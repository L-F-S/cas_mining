# %% [markdown]
#  <h1><center>Cas mining summary and data exploration + new Cas9 example</center></h1>

# %% [markdown]
# ## 1. Preliminary Data Exploration
# - ### 1.1 Total number of CRISPR/Cas elements found
# - ### 1.2 Data exploration per datasets
# - ### 1.3 Data exploration per SGBs
#
# ## 2. Cas9 Mining Example: cibiobacter
# - ### 2.1 Looking for Cas9 inside cibiobacter genomes
# - ### 2.2 retrieving the sequence
# - ### 2.3 Cas9 Sequence from one _cibiobacter_ genome
# - ### 2.4 Extracting Cas9 for all the 23 cibiobacter genomes and alligning them to get a cibiobacter cas9 consensus sequence
# - ### 2.5 Consensus sequence for _cibiobacter_ cas9
# - ### 2.6 Comparison between _cibiobacter_ and Streptococcus pyogenes Cas9

# %% [markdown]
# <div style="text-align: right">Lorenzo federico Signorini, 16/07/2019</div>
#
# <div style="text-align: right">Università degli studi di Trento</div>

# %% [markdown]
# # 1. Preliminary Data Exploration

# %%
# First created Thu Jul 11 09:51:15 CEST 2019
# Made by L-F-S
# At the University Of Trento, Italy

import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from Bio import SeqIO



sys.path.insert(0, '/home/lorenzo.signorini/utils/')
import filename_discrepancies


dataset="ZellerG_2014" #sys.argv[1] #TODO switch test dataset
tabledir="/shares/CIBIO-Storage/CM/scratch/tmp_projects/signorini_cas/3tabellazza" 
CRISPRdir="/shares/CIBIO-Storage/CM/scratch/tmp_projects/signorini_cas/1crisprsearch/out"
annodir="/shares/CIBIO-Storage/CM/scratch/tmp_projects/signorini_cas/2casanno/crisprcasanno"
datadir="/shares/CIBIO-Storage/CM/scratch/tmp_projects/signorini_cas/"

# %%
DF=pd.read_csv(tabledir+"/crisprcas_hits_table.csv", index_col=0)
print(DF.columns)
print(DF.shape)
print(DF.head(1))
# Out:
# Index(['Unnamed: 0.1', 'Genome Name', 'Study', 'Sample Name', 'Assembler',
#        'Genome Size', 'N50', '# Contigs', 'Completeness', 'Contamination',
#        'Strain Heterogeneity', 'SGB ID', 'pilercr_CRISPR', 'minced_CRISPR',
#        'prokka_CRISPR', 'prokka_cas', 'uniref_cas'],
#       dtype='object')
# (154723, 17)
#    Unnamed: 0.1                           Genome Name          Study  \
# 0             0  AsnicarF_2017__MV_FEI1_t1Q14__bin.10  AsnicarF_2017
#
#      Sample Name   Assembler  Genome Size   N50  # Contigs  Completeness  \
# 0  MV_FEI1_t1Q14  metaSPAdes      2013732  6532        403     84.646697
#
#    Contamination  Strain Heterogeneity  SGB ID pilercr_CRISPR minced_CRISPR  \
# 0       1.651306              1.458714   17248            NaN           NaN
#
#   prokka_CRISPR prokka_cas uniref_cas
# 0           NaN        NaN        NaN

# %%
crisprdf=DF[[DF.columns[1], DF.columns[2], DF.columns[12], DF.columns[13], DF.columns[14], DF.columns[15]]]
print(crisprdf.columns)
# Out:
# Index(['Genome Name', 'Study', 'pilercr_CRISPR', 'minced_CRISPR',
#        'prokka_CRISPR', 'prokka_cas'],
#       dtype='object')

# %%
DF.memory_usage()
# Out:
# Index                   1237784
# Unnamed: 0.1            1237784
# Genome Name             1237784
# Study                   1237784
# Sample Name             1237784
# Assembler               1237784
# Genome Size             1237784
# N50                     1237784
# # Contigs               1237784
# Completeness            1237784
# Contamination           1237784
# Strain Heterogeneity    1237784
# SGB ID                  1237784
# pilercr_CRISPR          1237784
# minced_CRISPR           1237784
# prokka_CRISPR           1237784
# prokka_cas              1237784
# dtype: int64

# %% [markdown]
# ##  1.1 Total number of CRISPR/Cas elements found:

# %%
groupedbyds=crisprdf.groupby(crisprdf.Study)

# %%
print("TOTAL number of CRISPR repeats found with pilerCR: ", groupedbyds.apply(lambda x : x.pilercr_CRISPR.str.count(">").sum()).sum())
print("TOTAL number of CRISPR repeats found with minced:  ", groupedbyds.apply(lambda x : x.minced_CRISPR.str.count(">").sum()).sum())
print("TOTAL number of Cas genes annotated with prokka:   ", groupedbyds.apply(lambda x : x.prokka_cas.str.count(">").sum()).sum())
print("TOTAL number of Cas9 genes annotated with prokka:   ", groupedbyds.apply(lambda x : x.prokka_cas.str.count("Cas9").sum()).sum())
# Out:
# TOTAL number of CRISPR repeats found with pilerCR:  92864.0
# TOTAL number of CRISPR repeats found with minced:   111462.0
# TOTAL number of Cas genes annotated with prokka:    283190.0
# TOTAL number of Cas9 genes annotated with prokka:    33978.0

# %% [markdown]
# ## 1.2 Data exploration per datasets:
# ###  # Repeats per dataset

# %%
groupedbyds.apply(lambda x : x.pilercr_CRISPR.str.count(">").sum()).plot(kind="bar", title="# Repeats", figsize=(10,15), color="b", alpha=0.5)
groupedbyds.apply(lambda x : x.minced_CRISPR.str.count(">").sum()).plot(kind="bar", color="orange", alpha=0.5)
plt.legend(("pilercr_CRISPR", "minced_CRISPR"))

# %% [markdown]
# ###  Avg # repeats per genome, per dataset

# %%
groupedbyds.apply(lambda x : x.pilercr_CRISPR.str.count(">").mean()).plot(kind="bar", title="avg # Repeats per genome", style=".-", figsize=(10,15), color="b", alpha=0.5)
groupedbyds.apply(lambda x : x.minced_CRISPR.str.count(">").mean()).plot(kind="bar",color="orange", alpha=0.5)
plt.legend(("pilercr_CRISPR", "minced_CRISPR"))

# %% [markdown]
# ### # Cas per dataset

# %%
groupedbyds.apply(lambda x : x.pilercr_CRISPR.str.count(">").sum()).plot(kind="bar", title="# Cas per dataset",figsize=(10,15), color="green", alpha=0.5)

# %% [markdown]
# ###  avg # cas per genome per dataset

# %%
groupedbyds.apply(lambda x : x.prokka_cas.str.count(">").mean()).plot(kind="bar", title="avg # Cas per genome",figsize=(10,15), color="green", alpha=0.5)

# %% [markdown]
# ## 1.3 Data exploration per SGBs
# SGBs (Species-level Genome Bins) are the metagenomic equivalent of a bacterial _species_ . There are 4,930 species-level genome bins in this dataset.

# %% [markdown]
# ### Avg #CRISPR per SGB

# %%
groupedbySGB=DF.groupby("SGB ID")


pilercr_avg_count_by_SGB=groupedbySGB.apply(lambda x : x.pilercr_CRISPR.str.count(">").mean()).sort_values()
minced_avg_count_by_SGB=groupedbySGB.apply(lambda x : x.minced_CRISPR.str.count(">").mean()).sort_values()

# %%
pilercr_avg_count_by_SGB.dropna().plot(kind="barh", title="avg # CRISPR per SGB",figsize=(10,90), color="b", alpha=0.5)

minced_avg_count_by_SGB.dropna().plot(kind="barh", color="orange", alpha=0.5)

# %%
# I wonder, what's that blue line there? It must be an SGB where only pilercr has found repeats
#print(minced_avg_count_by_SGB.index)
#for i in minced_avg_count_by_SGB.index:
 #   diff=abs(minced_avg_count_by_SGB[i] - pilercr_avg_count_by_SGB[i])
  #  if diff > 1:
   #     print(i, " : diff", diff)

# %%
#print(minced_avg_count_by_SGB[957],pilercr_avg_count_by_SGB[957])

# %% [markdown]
# ### Avg #Cas per SGB

# %%
cas_avg_count_by_sgb=groupedbySGB.apply(lambda x : x.prokka_cas.str.count(">").mean()).sort_values()
cas_avg_count_by_sgb.dropna().plot(kind="bar", title="avg # Cas per SGB", figsize=(10,15), color="green", alpha=0.5)

# %%
print(cas_avg_count_by_sgb[cas_avg_count_by_sgb>4])
# Out:
# SGB ID
# 1928      4.031250
# 2037      4.040000
# 8010      4.080000
# 6007      4.083333
# 9293      4.083333
# 4648      4.086957
# 9303      4.090909
# 9281      4.092308
# 6067      4.095238
# 8005      4.100000
# 5266      4.125000
# 6705      4.125000
# 5099      4.130435
# 714       4.133929
# 16987     4.136364
# 5051      4.137931
# 7962      4.140845
# 15177     4.142857
# 6271      4.142857
# 6293      4.142857
# 5742      4.142857
# 5090      4.150943
# 1860      4.152542
# 5904      4.160000
# 5869      4.166667
# 5061      4.176471
# 6571      4.191781
# 5843      4.200000
# 9225      4.200000
# 6934      4.200000
#            ...
# 15341    11.000000
# 6733     11.000000
# 6641     11.000000
# 6283     11.000000
# 5829     11.000000
# 6931     11.000000
# 4476     11.285714
# 6622     11.363636
# 8041     11.500000
# 6693     11.500000
# 5806     12.000000
# 4490     12.000000
# 4574     12.000000
# 15887    12.000000
# 6782     12.000000
# 4556     12.000000
# 6763     12.000000
# 4492     12.000000
# 5896     12.333333
# 5760     13.000000
# 17098    13.000000
# 8151     13.000000
# 15330    13.000000
# 4628     14.000000
# 6775     14.000000
# 6926     14.000000
# 15223    15.500000
# 8831     16.000000
# 15404    22.000000
# 4837     27.000000
# Length: 691, dtype: float64

# %% [markdown]
# ### 7. total # CRISPR per SGB da finire/da fare

# %%
pilercr_count_by_SGB=groupedbySGB.apply(lambda x : x.pilercr_CRISPR.str.count(">").sum()).sort_values()
minced_count_by_SGB=groupedbySGB.apply(lambda x : x.minced_CRISPR.str.count(">").sum()).sort_values()

# %%
#just checking. Should return true if everything works. 
len(pilercr_count_by_SGB[pilercr_count_by_SGB!=0])==len(pilercr_avg_count_by_SGB.dropna())
# Out:
# True

# %% [markdown]
# ## shortest working cas9 from most unknown genome

# %%
# Extract sequence information from GENOMES WITH <cas9> annotation.
feature="Cas9"
tabellazza=pd.read_csv(datadir+"/3tabellazza/crisprcas_hits_table.csv", index_col=0)
SGBs=pd.read_excel(datadir+"S4Segata.xlsx")
# OPTIONAL TODO : subsample for a single SGB
#chosen_SGB=15286  # Cibiobacter SGB
#single_SGB=tabellazza[tabellazza["SGB ID"]==chosen_SGB]
#subset_of_genomes=single_SGB 

subset_of_genomes=tabellazza

genomes_with_that_feature=subset_of_genomes[subset_of_genomes.prokka_cas.str.contains(feature)==True]
print("Found ", len(genomes_with_that_feature), " genomes with that feature.")
# Out:
# Found  29980  genomes with that feature.

# %%
for index, genome in genomes_with_that_feature.iterrows():
    print("\n-----------------------------------------------------\nGenome Name:\t",genome["Genome Name"],"\n-----------------------------------------------------")
    #print("Cas proteins:")
    featureanno=genome.prokka_cas.lstrip(">").split(">")
    if not type(genome.minced_CRISPR)==float:
        CRISPRanno=genome.minced_CRISPR.lstrip(">").split(">")

    else:
#        print("*******************************************************************")
 #       if not type(genome.pilercr_CRISPR)==float:
  #          CRISPRanno=genome.pilercr_CRISPR.lstrip(">").split(">")
   #     else:
        CRISPRanno=[]
    list_of_annotations=featureanno + CRISPRanno 
    contigs=np.unique([anno.split("\t")[0] for anno in list_of_annotations])    
    anno_on_contig={}
  #  print(contigs)
    for contig in contigs:
        anno_on_contig[contig] = [(x.split("\t")[3], x.split("\t")[4], x[x.index("product")+8:x.index("product")+90]) for x in featureanno if contig == x.split("\t")[0]] 
        anno_on_contig[contig] += [(x.split("\t")[3],x.split("\t")[4],x.split("\t")[8][x.split("\t")[8].index("ID")+3:x.split("\t")[8].index("ID")+10]) for x in CRISPRanno if contig == x.split("\t")[0]]  
    for contig in anno_on_contig.keys():
        print("\t---------------------------------------------\n\tContig:\t",
              contig,"\n\t---------------------------------------------")
        length=int(contig.split("_")[3])
        for anno in anno_on_contig[contig]:
            print("\t",anno[2], "start:", int(anno[0]), "stop:", int(anno[1]))
# Out:
# -----------------------------------------------------
# Genome Name:	 AsnicarF_2017__MV_FEI4_t1Q14__bin.1
# -----------------------------------------------------
# 	---------------------------------------------
# 	Contig:	 NODE_1073_length_1994_cov_2.17225
# 	---------------------------------------------
# 	 CRISPR-associated endonuclease Cas9/Csn1;protein_id=gnl|X|EIBEGOMO_01279 start: 141 stop: 608
#
# -----------------------------------------------------
# Genome Name:	 AsnicarF_2017__MV_FEI4_t1Q14__bin.4
# -----------------------------------------------------
# 	---------------------------------------------
# 	Contig:	 NODE_45_length_75974_cov_38.2495
# 	---------------------------------------------
# 	 CRISPR-associated endonuclease Cas9;protein_id=gnl|X|KBEGFPIJ_01435 start: 32341 stop: 36870
# 	 CRISPR-associated endonuclease Cas1;protein_id=gnl|X|KBEGFPIJ_01437 start: 37910 stop: 38842
# 	 CRISPR-associated endoribonuclease Cas2;protein_id=gnl|X|KBEGFPIJ_01438 start: 38842 stop: 39180
# 	 CRISPR1 start: 39283 stop: 40172
# 	---------------------------------------------
# 	Contig:	 NODE_75_length_55806_cov_51.1227
# 	---------------------------------------------
# 	 CRISPR-associated endoribonuclease Cas2;protein_id=gnl|X|KBEGFPIJ_02066 start: 2010 stop: 2300
# 	 CRISPR-associated endonuclease Cas1;protein_id=gnl|X|KBEGFPIJ_02067 start: 2310 stop: 3332
# 	 CRISPR pre-crRNA endoribonuclease Cas5d;protein_id=gnl|X|KBEGFPIJ_02071 start: 6595 stop: 7296
# 	 CRISPR2 start: 1422 stop: 1844
#
# -----------------------------------------------------
# Genome Name:	 AsnicarF_2017__MV_FEI4_t2Q15__bin.2
# -----------------------------------------------------
# 	---------------------------------------------
# 	Contig:	 NODE_51_length_94666_cov_13.1517
# 	---------------------------------------------
# 	 CRISPR-associated endoribonuclease Cas2;protein_id=gnl|X|OBHKLEMF_00862 start: 23970 stop: 24275
# 	 CRISPR-associated endonuclease Cas1;protein_id=gnl|X|OBHKLEMF_00863 start: 24253 stop: 25158
# 	 CRISPR-associated endonuclease Cas9;protein_id=gnl|X|OBHKLEMF_00864 start: 25358 stop: 29455
# 	 CRISPR1 start: 21587 stop: 23272
#
# -----------------------------------------------------
# Genome Name:	 AsnicarF_2017__MV_FEI4_t2Q15__bin.5
# -----------------------------------------------------
# 	---------------------------------------------
# 	Contig:	 NODE_70_length_82951_cov_19.4828
# 	---------------------------------------------
# 	 CRISPR-associated endoribonuclease Cas2;protein_id=gnl|X|EPJEOPIP_01090 start: 26249 stop: 26554
# 	 CRISPR-associated endonuclease Cas1;protein_id=gnl|X|EPJEOPIP_01091 start: 26532 stop: 27437
# 	 CRISPR-associated endonuclease Cas9/Csn1;protein_id=gnl|X|EPJEOPIP_01092 start: 27653 stop: 31726
# 	 CRISPR1 start: 24197 stop: 25552
#
# -----------------------------------------------------
# Genome Name:	 AsnicarF_2017__MV_FEI5_t1Q14__bin.12
# -----------------------------------------------------
# 	---------------------------------------------
# 	Contig:	 NODE_123_length_29049_cov_29.8501
# 	---------------------------------------------
# 	 CRISPR-associated endoribonuclease Cas2;protein_id=gnl|X|AHBHJMAE_01495 start: 6974 stop: 7318
# 	 CRISPR-associated endonuclease Cas1;protein_id=gnl|X|AHBHJMAE_01496 start: 7315 stop: 8232
# 	 CRISPR-associated endonuclease Cas9;protein_id=gnl|X|AHBHJMAE_01497 start: 8232 stop: 11426
# 	 CRISPR1 start: 11506 stop: 13060
#
# -----------------------------------------------------
# Genome Name:	 AsnicarF_2017__MV_FEI5_t2Q14__bin.2
# -----------------------------------------------------
# 	---------------------------------------------
# 	Contig:	 NODE_225_length_24753_cov_68.7088
# 	---------------------------------------------
# 	 CRISPR-associated endoribonuclease Cas2;protein_id=gnl|X
# 	---------------------------------------------
# 	 CRISPR-associated endonuclease Cas9;protein_id=gnl|X|CAINGIJL_01966 start: 720 stop: 1631
# 	---------------------------------------------
# 	Contig:	 NODE_5945_length_3110_cov_2.84419
# 	---------------------------------------------
# 	 CRISPR-associated protein Cas10/Csm1;protein_id=gnl|X|CAINGIJL_01387 start: 42 stop: 1619
# 	 CRISPR type III-associated protein Csm2;protein_id=gnl|X|CAINGIJL_01388 start: 1606 stop: 1980
# 	 CRISPR type III-associated RAMP protein Csm3;protein_id=gnl|X|CAINGIJL_01389 start: 2004 stop: 2663
#
# -----------------------------------------------------
# Genome Name:	 AsnicarF_2017__MV_FEM3_t1Q14__bin.28
# -----------------------------------------------------
# 	---------------------------------------------
# 	Contig:	 NODE_181_length_47926_cov_5.94611
# 	---------------------------------------------
# 	 CRISPR-associated endonuclease Cas9 2;protein_id=gnl|X|NMGNGHIO_00194 start: 18010 stop: 22059
# 	 CRISPR-associated endonuclease Cas1;protein_id=gnl|X|NMGNGHIO_00195 start: 22056 stop: 22928
# 	 CRISPR-associated endoribonuclease Cas2;protein_id=gnl|X|NMGNGHIO_00196 start: 22921 stop: 23244
# 	 CRISPR1 start: 23972 stop: 24337
#
# -----------------------------------------------------
# Genome Name:	 AsnicarF_2017__MV_FEM3_t1Q14__bin.32
# -----------------------------------------------------
# 	---------------------------------------------
# 	Contig:	 NODE_146_length_54121_cov_15.3513
# 	---------------------------------------------
# 	 CRISPR-associated endonuclease Cas9;protein_id=gnl|X|ODJFGKEJ_01916 start: 155 stop: 403
#
# -----------------------------------------------------
# Genome Name:	 AsnicarF_2017__MV_FEM3_t1Q14__bin.8
# -----------------------------------------------------
# 	---------------------------------------------
# 	Contig:	 NODE_2217_length_7210_cov_5.40154
# 	---------------------------------------------
# 	 CRISPR-associated endonuclease Cas9;protein_id=gnl|X|AFONOMOM_02900 start: 255 stop: 4781
# 	 CRISPR-associated endonuclease Cas1;protein_id=gnl|X|AFONOMOM_02902 start: 5655 stop: 6587
# 	 CRISPR-associated endoribonuclease Cas2;protein_id=gnl|X|AFONOMOM_02903 start: 6587 stop: 6919
# 	---------------------------------------------
# 	Contig:	 NODE_9527_length_2046_cov_2.89704
# 	---------------------------------------------
# 	 CRISPR-associated endonuclease Cas1;protein_id=gnl|X|AFONOMOM_05332 start: 353 stop: 1282
# 	 CRISPR-associated endoribonuclease Cas2;protein_id=gnl|X|AFONOMOM_05333 start: 1248 stop: 1616
# 	 CRISPR1 start: 1725 stop: 2002
#
# -----------------------------------------------------
# Genome Name:	 AsnicarF_2017__MV_FEM4_t1Q14__bin.11
# -----------------------------------------------------
# 	---------------------------------------------
# 	Contig:	 NODE_2026_length_5100_cov_3.94708
# 	---------------------------------------------
# 	 CRISPR-associated endoribonuclease Cas2;protein_id=gnl|X|IDCMCJMI_01783 start: 656 stop: 961
# 	 CRISPR-associated endonuclease Cas1;protein_id=gnl|X|IDCMCJMI_01784 start: 1137 stop: 1838
# 	 CRISPR-associated endonuclease Cas9;protein_id=gnl|X|IDCMCJMI_01785 start: 1835 stop: 5098
#
# -----------------------------------------------------
# Genome Name:	 AsnicarF_2017__MV_FEM4_t2Q15__bin.1
# -----------------------------------------------------
# 	---------------------------------------------
# 	Contig:	 NODE_1262_length_10322_cov_14.5369
# 	---------------------------------------------
# 	 CRISPR4 start: 258 stop: 1756
# 	---------------------------------------------
# 	Contig:	 NODE_3561_length_5017_cov_10.005
# 	---------------------------------------------
# 	 CRISPR system Cascade subunit CasC;protein_id=gnl|X|COHKHJGM_01587 start: 940 stop: 2007
# 	 CRISPR system Cascade subunit CasD;protein_id=gnl|X|COHKHJGM_01588 start: 2021 stop: 2746
# 	 CRISPR-associated endoribonuclease Cse3;protein_id=gnl|X|COHKHJGM_01589 start: 2751 stop: 3389
# 	 CRISPR-associated endonuclease Cas1;protein_id=gnl|X|COHKHJGM_01590 start: 3393 stop: 4334
# 	---------------------------------------------
# 	Contig:	 NODE_665_length_16038_cov_15.7868
# 	---------------------------------------------
# 	 CRISPR1 start: 6333 stop: 6635
# 	---------------------------------------------
# 	Contig:	 NODE_904_length_13060_cov_14.219
# 	---------------------------------------------
# 	 CRISPR-associated endonuclease Cas9 1;protein_id=gnl|X|COHKHJGM_01006 start: 30 stop: 425
# 	 CRISPR-associated endonuclease Cas1;protein_id=gnl|X|COHKHJGM_01007 start: 602 stop: 1513
# 	 CRISPR-associated endoribonuclease Cas2;protein_id=gnl|X|COHKHJGM_01008 start: 1515 stop: 1838
# 	 CRISPR2 start: 2950 stop: 4768
# 	---------------------------------------------
# 	Contig:	 NODE_979_length_12294_cov_12.8421
# 	---------------------------------------------
# 	 CRISPR type III-associated RAMP protein Csm4;protein_id=gnl|X|COHKHJGM_01067 start: 105 stop: 1004
# 	 CRISPR type III-associated RAMP protein Csm3;protein_id=gnl|X|COHKHJGM_01068 start: 1006 stop: 1668
# 	 CRISPR type III-associated protein Csm2;protein_id=gnl|X|COHKHJGM_01069 start: 1668 stop: 2048
# 	 CRISPR-associated protein Cas10/Csm1;protein_id=gnl|X|COHKHJGM_01070 start: 2052 stop: 4328
# 	 CRISPR-associated endoribonuclease Cas6;protein_id=gnl|X|COHKHJGM_01071 start: 4309 stop: 5040
# 	 CRISPR-associated endoribonuclease Cas2;protein_id=gnl|X
# 	---------------------------------------------
# 	 CRISPR-associated endonuclease Cas9;protein_id=gnl|X|MDDHMGNE_01021 start: 6997 stop: 7362
# 	 CRISPR1 start: 16 stop: 241
# 	---------------------------------------------
# 	Contig:	 NODE_745_length_18345_cov_3.58207
# 	---------------------------------------------
# 	 CRISPR-associated endonuclease Cpf1;protein_id=gnl|X|MDDHMGNE_00789 start: 14437 stop: 18123
#
# -----------------------------------------------------
# Genome Name:	 BackhedF_2015__SID598_12M__bin.6
# -----------------------------------------------------
# 	---------------------------------------------
# 	Contig:	 NODE_153_length_70998_cov_33.608
# 	---------------------------------------------
# 	 CRISPR1 start: 16774 stop: 19773
# 	---------------------------------------------
# 	Contig:	 NODE_501_length_27450_cov_33.0515
# 	---------------------------------------------
# 	 CRISPR-associated endoribonuclease Cas2;protein_id=gnl|X|PBFAHIDD_02795 start: 8208 stop: 8528
# 	 CRISPR-associated endonuclease Cas1;protein_id=gnl|X|PBFAHIDD_02796 start: 8521 stop: 9426
# 	 CRISPR-associated endonuclease Cas9;protein_id=gnl|X|PBFAHIDD_02797 start: 9445 stop: 12867
#
# -----------------------------------------------------
# Genome Name:	 BackhedF_2015__SID598_4M__bin.13
# -----------------------------------------------------
# 	---------------------------------------------
# 	Contig:	 NODE_437_length_19929_cov_20.3485
# 	---------------------------------------------
# 	 CRISPR-associated endonuclease Cas9;protein_id=gnl|X|MDPEINKB_00775 start: 11453 stop: 14908
# 	 CRISPR-associated endonuclease Cas1;protein_id=gnl|X|MDPEINKB_00776 start: 14912 stop: 15817
# 	 CRISPR-associated endoribonuclease Cas2;protein_id=gnl|X|MDPEINKB_00777 start: 15814 stop: 16146
# 	 CRISPR1 start: 16197 stop: 18737
#
# -----------------------------------------------------
# Genome Name:	 BackhedF_2015__SID598_4M__bin.14
# -----------------------------------------------------
# 	---------------------------------------------
# 	Contig:	 NODE_2333_length_1989_cov_3.11789
# 	---------------------------------------------
# 	 CRISPR-associated endonuclease Cas9;protein_id=gnl|X|FFHGJPKL_01122 start: 27 stop: 956
# 	 CRISPR-associated endonuclease Cas1;protein_id=gnl|X|FFHGJPKL_01123 start: 956 stop: 1846
#
# -----------------------------------------------------
# Genome Name:	 BackhedF_2015__SID598_4M__bin.15
# -----------------------------------------------------
# 	---------------------------------------------
# 	Contig:	 NODE_23_length_185642_cov_21.9063
# 	---------------------------------------------
# 	 CRISPR-associated endonuclease Cas9;protein_id=gnl|X|CDDLKDEN_00808 start: 118625 stop: 121819
# 	 CRISPR-associated endonuclease Cas1;protein_id=gnl|X|CDDLKDEN_00809 start: 121840 stop: 122736
# 	 CRISPR-associated endoribonuclease Cas2;protein_id=gnl|X|CDDLKDEN_00810 start: 122733 stop: 123077
# 	 CRISPR1 start: 117984 stop: 118481
#
# -----------------------------------------------------
# Genome Name:	 BackhedF_2015__SID598_4M__bin.16
# -----------------------------------------------------
# 	---------------------------------------------
# 	Contig:	 NODE_2043_length_2452_cov_3.05465
# 	---------------------------------------------
# 	 CRISPR type III-associated RAMP protein Csm3;protein_id=gnl|X|GDIINHKE_01687 start: 915 stop: 1631
# 	---------------------------------------------
# 	Contig:	 NODE_616_length_12552_cov_4.66712
# 	---------------------------------------------
# 	 CRISPR-associated endonuclease Cas9;protein_id=gnl|X|GDIINHKE_00296 start: 4860 stop: 9128
# 	 CRISPR-associated endonuclease Cas1 1;protein_id=gnl|X|GDIINHKE_00297 start: 9125 stop: 10138
# 	 CRISPR-associated endoribonuclease Cas2 1;protein_id=gnl|X|GDIINHKE_00298 start: 10151 stop: 10447
# 	 CRISPR-associated exonuclease Cas4;protein_id=gnl|X|GDIINHKE_00299 start: 10434 stop: 11021
# 	 CRISPR1 start: 11330 stop: 12464
# 	---------------------------------------------
# 	Contig:	 NODE_861_length_7835_cov_3.20707
# 	---------------------------------------------
# 	 CRISPR-associated protein Cas10/Csm1;protein_id=gnl|X|GDIINHKE_00608 start: 694 stop: 2142
# 	 CRISPR-associated endoribonuclease Cas2;protein_id=gnl|X|GDIINHKE_00615 start: 6922 stop: 7203
#
# -----------------------------------------------------
# Genome Name:	 BackhedF_2015__SID598_4M__bin.4
# -----------------------------------------------------
# 	---------------------------------------------
# 	Contig:	 NODE_258_length_35283_cov_39.4422
# 	---------------------------------------------
# 	 CRISPR-associated endoribonuclease Cas2;protein_id=gnl|X|OMECHPBJ_03203 start: 17832 stop: 18164
# 	 CRISPR-associated endonuclease Cas1;protein_id=gnl|X|OMECHPBJ_03204 start: 18164 stop: 19093
# 	 CRISPR-associated endonuclease Cas9;protein_id=gnl|X|OMECHPBJ_03205 start: 19555 stop: 23838
# 	 CRISPR1 start: 17293 stop: 17723
#
# -----------------------------------------------------
# Genome Name:	 BackhedF_2015__SID598_B__bin.4
# -----------------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-4515d68c070f> in <module>
#      13         CRISPRanno=[]
#      14     list_of_annotations=featureanno + CRISPRanno
# ---> 15     contigs=np.unique([anno.split("\t")[0] for anno in list_of_annotations])
#      16     anno_on_contig={}
#      17   #  print(contigs)
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/arraysetops.py in unique(ar, return_index, return_inverse, return_counts, axis)
#     262     ar = np.asanyarray(ar)
#     263     if axis is None:
# --> 264         ret = _unique1d(ar, return_index, return_inverse, return_counts)
#     265         return _unpack_tuple(ret)
#     266
#
# ~/anaconda3/lib/python3.7/site-packages/numpy/lib/arraysetops.py in _unique1d(ar, return_index, return_inverse, return_counts)
#     310         aux = ar[perm]
#     311     else:
# --> 312         ar.sort()
#     313         aux = ar
#     314     mask = np.empty(aux.shape, dtype=np.bool_)
#
# KeyboardInterrupt:

# %% [markdown]
# ## sort sequences by length

# %%
cas9s={}
for index, genome in genomes_with_that_feature.iterrows():
    dataset=genome.Study
    genomename=genome["Genome Name"] #TODO Be careful for filename discrepancies, especially with ZeeviD files and with _megahit_ underscores!
  #  print("\n-----------------------------------------------------\nGenome Name:\t",genome["Genome Name"],"\n-----------------------------------------------------\n")

    
    ######################################################################
    # take into account filename discrepancies
    if dataset.startswith("ZeeviD"):
                   
             working_genomename=filename_discrepancies.change_to_megahit(genomename)
             try:
                 working_genomename=genomename.replace("ZeeviD_2015", "ZeeviD_2015_B")
                 prokkafile_ofsample=open(annodir+"/justminced/ZeeviD_2015_B/"+genomename+".crisprcas.gff.minced")
                 prokkafile_ofsample.close()
                 dataset="ZeeviD_2015_B"
             except:
                 working_genomename=genomename.replace("ZeeviD_2015_B", "ZeeviD_2015_A")
                 dataset="ZeeviD_2015_A"
        
    if filename_discrepancies.dataset_has_megahit(dataset,genomename):
        genomename=filename_discrepancies.change_to_megahit(genomename)
    ########################################################################

    path="/shares/CIBIO-Storage/CM/scratch/tmp_projects/epasolli_darkmatter/allcontigs/"+dataset+"/metabat/genomes_comp50_cont05/prokka/"+genomename    
    filename=path+"/"+genomename+".faa"
    

     
    for record in SeqIO.parse(filename, "fasta"):
        if "Cas9" in record.description:
            cas9s[(genomename, record.id)]=(record.seq, len(record.seq))
         #   genomes_with_that_feature["Cas9 Sequence len"]=len(str(record.seq))
          #  genomes_with_that_feature["Cas9 Sequence"]=str(record.seq)
           # print(len(record.seq),"\n", record.id)
#print(genomes_with_that_feature.['Cas9 Sequence'])
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-c0e2686097e9> in <module>
#      28
#      29
# ---> 30     for record in SeqIO.parse(filename, "fasta"):
#      31         if "Cas9" in record.description:
#      32             cas9s[(genomename, record.id)]=(record.seq, len(record.seq))
#
# ~/anaconda3/lib/python3.7/site-packages/Bio/SeqIO/__init__.py in parse(handle, format, alphabet)
#     634         raise ValueError("Invalid alphabet, %r" % alphabet)
#     635
# --> 636     with as_handle(handle, mode) as fp:
#     637         # Map the file format to a sequence iterator:
#     638         if format in _FormatToIterator:
#
# ~/anaconda3/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# ~/anaconda3/lib/python3.7/site-packages/Bio/File.py in as_handle(handleish, mode, **kwargs)
#     111                 yield fp
#     112         else:
# --> 113             with open(handleish, mode, **kwargs) as fp:
#     114                 yield fp
#     115     else:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/shares/CIBIO-Storage/CM/scratch/tmp_projects/epasolli_darkmatter/allcontigs/Bengtsson-PalmeJ_2015/metabat/genomes_comp50_cont05/prokka/Bengtsson-PalmeJ_2015__TRAVELRES1__bin.110/Bengtsson-PalmeJ_2015__TRAVELRES1__bin.110.faa'

# %%
genomes_with_that_feature.sort_values(genomes_with_that_feature['Cas9 Sequence len'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Cas9 Sequence len'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-1428c595f1fa> in <module>
# ----> 1 genomes_with_that_feature.sort_values(genomes_with_that_feature['Cas9 Sequence len'])
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Cas9 Sequence len'
